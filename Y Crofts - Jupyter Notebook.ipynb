# %% [markdown]
# <div class="alert alert-block alert-info">
# <h1><center>My Jupyter Notebook on IBM Watson Studio</center></h1>
# </div>

# %% [markdown]
# <h1>Yachel Crofts</h1>
#     Data Scientist

# %% [markdown]
# _I am interested in Data Science because it is a valuable tool for helping us better understand the world around us_ <br>
# _Data is the lanuage of the modern age and we Data Scientist are translators bridging the gap between the unseen world of Data and the Human Race_

# %% [markdown]
# <h3> The cell below, which is cell 5, demostrates the simple mathematical equation  4+4*5</h3>

# %%
4+4*5
# Out:
# 24

# %% [markdown]
# ***
# ***
# ***
# <h3> My favourite actors </h3>
#
# * Jim Carrey
# * Arnold Scharzernegger
# * Steve Corel
# * Will Ferrel
# * Brad pit
#
# <h3> My top 5 favourite fruits </h3>
#
#  1. Bananas
#  1. Pineapples
#  1. Oranges
#  1. Peaches
#  1. Strawberries
#
# <h3> Some great cars with specs </h3>
#
#
#  | Car | Horsepower | Cylinders | Top Speed MPH |
#  | --- | --- | --- | --- |
#  |Dodge Viper | 405HP | 10 | 205MPH |
#  |Ford Mustang GT350 | 350HP | 8 | 190MPH |
#  |Lamborghini Contache | 430HP | 12 | 186MPH |
#  |Porsche 356 | 104HP | 4 | 120MPH |
#  |Subaru Forester XT | 240HP | 4 | 130 |
#
#  __<h3>[Here is a link to an interesting article about a very unique car](https://www.topgear.com/car-news/big-reads/crazy-story-porsche-356-thats-raced-around-world)</h3>__
#
# ![800px-SNice.svg.png](attachment:800px-SNice.svg.png)
